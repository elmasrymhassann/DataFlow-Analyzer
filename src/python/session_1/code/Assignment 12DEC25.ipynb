# %%
x= "Amit_ml@gmai.edu"
print (x)

try:
     Store1= x.split("@")[1]
except IndexError:
       ("No domain found")
       print("Invalid email")
try:
    Store2= x.split(".")[1]
except IndexError:
        print ("wrong email extension found")
# Out:
# Amit_ml@gmai.edu
