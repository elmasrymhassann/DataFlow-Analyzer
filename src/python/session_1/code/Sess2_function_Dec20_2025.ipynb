# %%
def sum_100 (num1,num2):
    return num1 + num2

# %%
sum_100(10,20)
# Out:
# 30

# %%
path="C:/Users/Almasry/DataFlow-Analyzer/DataFlow-Analyzer/src/python/session_1/code"
type(path)
# Out:
# str

# %%
import os
os.listdir(path)
# Out:
# ['As2 Dec12_25.ipynb',
#  'As2 Dec12_25_3and4.ipynb',
#  'As2 Dec12_25_4.ipynb',
#  'Assignment 12DEC25.ipynb',
#  'basic.ipynb',
#  'Sess2_function_Dec20_2025.ipynb',
#  'Sess_Dec13_25.ipynb',
#  'Sess_Dec19_2025.ipynb',
#  'Sess_Dec20_205.ipynb']
