# %%
print("Hello, World!   ")
# Out:
# Hello, World!

# %%
def get(name, age):
    return f"My name is {name} and I am {age} years old."

get("Alice", 30)
# Out:
# 'My name is Alice and I am 30 years old.'

# %%
n = input()
a = input()

def get2(name, age):

    return f"my name is : {name} and I am {age} years old."

get2(n, a)
# Out:
# 'my name is : s and I am 2 years old.'

# %%
def get2(name, age):
    name= input()
    age = int(input())

    return f"my name is : {name} and I am {age} years old."

get2("x", 2) # you force your self to send two parameters when calling the function
# Out:
# 'my name is : h and I am 2 years old.'

# %%
def sum(a, b):
    return a + b

def mul(a, b):
    return a * b

def sub(a,b):
    return a-b
