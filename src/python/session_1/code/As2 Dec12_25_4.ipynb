# %%
x1 = "##$$$@!yalpstcejorp EPUVT****9887"
y1 = x1.strip("#$@s!*9877")
Store_y1 = y1.split(" ")[0] 

Store_y1= Store_y1[::-1]
print(Store_y1)


Store_y2 = y1.split(" ")[1]
print(Store_y2)
Store_y2 = Store_y2.replace("E", "A").replace("U", "O")
print(Store_y1 +" "+ Store_y2)
