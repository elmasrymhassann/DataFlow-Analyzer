# %%
list_one = [1,2,3,4, "amit", "learning", True,[1,2,3,"True",["ml","dl","GenAI"]]]
print(list_one)
print(type(list_one))
print(list_one[4])  # Output: amit

print(list_one[-1][-1][-1])  #printed last item in the nested list

print (list_one[7][4][2])  #printed last item in the nested list

list_one[-1][-1][-1] = " We change the last item"
print (list_one[-1][-1][-1])


# ADD ITEMS TO LIST

# ADD ITEMS TO LIST

Number = 3  ,4 ,6  # tuple
list(Number)  #converting tuple to list
print(list(Number))  # Output: [3, 4, 6]

list_tuple_number = 3  ,4 ,6  # tuple
list_tuple_number = list(list_tuple_number)
print(list_tuple_number)  # Output: [3, 4, 6]
list_tuple_number.insert(0,"Mohamed")  #tuples are immutable we cannot add or remove items
print(list_tuple_number)  # Output: (3, 4, 6)

list_tuple_number.append("Amit")  #appending item to the list
print(list_tuple_number)  # Output: [3, 4, 6, '

del list_tuple_number[0]
 #deleting item from the list
# Out:
# [1, 2, 3, 4, 'amit', 'learning', True, [1, 2, 3, 'True', ['ml', 'dl', 'GenAI']]]
# <class 'list'>
# amit
# GenAI
# GenAI
#  We change the last item
# [3, 4, 6]
# [3, 4, 6]
# ['Mohamed', 3, 4, 6]
# ['Mohamed', 3, 4, 6, 'Amit']

# %%
inputlist = ["depi" , "Math", "Science","AI","ML"]
Value1 = input("enter you value = ")
inputlist.remove(Value1)
print(inputlist)
print(f"we removed {Value1} and the updated list is : {inputlist}")

# %%
sent_1 = "welcome into our company"
split_result = sent_1.split()
print(split_result)  # Output: ['welcome', 'into', 'our', 'company']
sent_2= ' * '.join(split_result)
type(sent_2)
print(type(sent_2)) # Output: "welcomeintoourcompany"
print(sent_2) 
#sent_1.startswith('welcome')  
sent_2.endswith('our')# Output: True
# Out:
# ['welcome', 'into', 'our', 'company']
# <class 'str'>
# welcome * into * our * company
# False

# %%
sent_1 = "depi learning depi"
sent_1.count("depi")
split_text = sent_1.split()
print(split_text)  # Output: ['depi', 'learning', 'depi']
print(sent_1.count("depi"))  # Output: 2


# split :return the text form in list form/shape
import math
math.cos(60)

sent_new = ''.join(split_text)
type(sent_new)
# Out:
# ['depi', 'learning', 'depi']
# 2
# str
