# %%
key_value =[('a',1),('b',2),('c',3)]
dict_4 = dict(key_value)
print(dict_4)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
num1= int(input("Enter first number: "))
num2= int(input("Enter second number: "))
sum = (num1) + (num2)

# Capsulation the input as Interget Capsula
# the sume of two integer
num4= (input("Enter third number: "))
num5= (input("Enter fourth number: "))
sum2 = (num4) + (num5)
# here the sum will be not as usual 
# because of no capsulation to data type of the input data
print("The sum of first two numbers is: ", sum)
print("The sum of last two numbers is: ", sum2)

# %%
a= int(input("Enter value for a: "))
b= int(input("Enter value for b: "))

if b> a:
    print("b is greater than a")
elif a == b : 
    print("a is equal to b")
else: 
 print("a is greater than b")
# Out:
# a is greater than b

# %%
is_raining = input("Is it raining? (yes/no): ")
if not is_raining == 'no':
    print("Take an umbrella.")
else: 
    print("No need for an umbrella.")
# Out:
# Take an umbrella.

# %%
x = int (input ("Enter a number: ")) 
result ="even" if x % 2 == 0 else "Odd"
print(result)
# Out:
# Odd

# %%
age = 21

# %%
dict_1= {"key1": 1, "key2": "value1", 4:[10,20,30]}
# 4 here used as data type of integer array
print(dict_1[4][0]) # print first item in the integer array 4
# Out:
# 10

# %%
set_1 = {1,2,3}
set_2 = {3,4,5}
print(set_1.intersection(set_2))
print(set_1.union(set_2))   
print(set_1.difference(set_2))
# Out:
# {3}
# {1, 2, 3, 4, 5}
# {1, 2}

# %%
tuple_1 = (1, 2, 3 )
print(type(tuple_1))
conv_list = list(tuple_1)
conv_list[2] = 1000
new_tuple= tuple(conv_list)
print(new_tuple)
# Out:
# <class 'tuple'>
# (1, 2, 1000)
