# %%
import string
x = "###!!@mocleW EPGTQ!!!6789"
y = x.strip("!@#6789")
#print(y)
y = y[::-1]
#print(y)
Store4 = y.split(" ")[1]
print(Store4)

store5 = y.split(" ")[0]
store5= store5[::-1]
print(store5)

B = "euiao"
store5 = store5.lower()
store6 = store5.strip(B)
store6 = store6.upper()
print(store6)
print(Store4 +" "+ store6) 
#  letters = list(string.ascii_uppercase)
#  print(letters)
# Out:
# Welcom
# EPGTQ
# PGTQ
# Welcom PGTQ

# %%
x1 = "###!!@mocleW EPGTQ!!!6789"
y1 = x1.strip("!@#6789")

y1= y1[::-1]
print(y1)

Store_y1 = y1.split(" ")[0]
Store_y2 = y1.split(" ")[1]
print(Store_y2 +" "+ Store_y1)
# Out:
# QTGPE Welcom
# Welcom QTGPE
