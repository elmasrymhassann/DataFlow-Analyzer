# %%
x1 = "&&&**$gnirtS PLIO!!@1234"
y1 = x1.strip("&*$!@1234") 
Store_y1 = y1.split(" ")[0] 

Store_y1= Store_y1[::-1]
print(Store_y1)


Store_y2 = y1.split(" ")[1]
print(Store_y2)
Store_y2 = Store_y2.replace("I", "E").replace("O", "U")
print(Store_y1 +" "+ Store_y2)
# Out:
# String
# PLIO
# String PLEU
