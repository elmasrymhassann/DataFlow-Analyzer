# %%
print("hello world")

x=30

Z = 50.33

type(x)
print(type(x))

print(id(x))

type(Z)

'''gjhj'''


name = "AMIT course mohamed @gmail.com "
print (name[11:17])
print (name[-11:-1])
print(name[1:10:3])

name = "Wlecome to seesion"
print(name.upper()) 
cap = name.lower()
print(cap)



rep = name.replace("seesion", "session")
print(rep)  


stock = "apple, orange, banana, kiwi"
print(stock.title())            

Editthestock = print("modification of cell no 2 ",stock.replace("orange", "fruit"))
# Out:
# hello world
# <class 'int'>
# 140730434973016
#  moham
# @gmail.com
# M u
# WLECOME TO SEESION
# wlecome to seesion
# Wlecome to session
# Apple, Orange, Banana, Kiwi
# modification of cell no 2  apple, fruit, banana, kiwi
